# %% [markdown]
# Recurrent Neural Networks (RNN)
# ====================
#
# In this exercise we will work with Recurrent Neural Networks (RNN). A RNN is class of neural networks where the output not only depends on the current input but also on previous inputs along a given input sequence. This allows to exhibit temporal dynamic behaviour and contextual information in a sequence. Common applications for RNN are:
#
# - time series analysis
# - speech recognition
# - machine translation
# - image captioning
#
#
# Goal of this exercise
# ========
#
# This exercise notebook should help you to experiment how recurrent neural networks are implemented, trained, and used for computer vision problems. Therefore, this notebook is structured as follows:
# 1. Implement your own simple RNN class in Pytorch.
# 2. Explore the backpropagation of the gradients in the RNN and discuss the vanishing gradient problem.
# 3. Implement your own LSTM (Long-Short Term Memory) Network and show that this architecture improves the vanishing gradient problem.
# 4. Build a RNN classifier for the MNIST dataset and train your model.
# 5. Tune the hyperparameters of your model and submit your best model to the server to get bonus points.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
import os

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
import platform
print('Using python: ', platform.python_version())
print('Using torch version: ', torch.__version__)
print('Using device: ', device)
# Machine: 2015 13" Macbook Pro, i5 dual core
# Out:
# Using python:  3.7.4
# Using torch version:  1.3.1
# Using device:  cpu

# %% [markdown]
# ## Simple Recurrent Neural Network
#
# The recurrent loops in a RNN allow relevant information to persist over time. A simple RNN architecture is shown here:
# <img src=http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/RNN-rolled.png width="150">
#
# A simple RNN takes not only an input X at time step t but also passes a hidden state that is the output of the previous time step into the network. The output of a RNN cell at time step t reads in Eq. 1:
#
# ![image.png](attachment:image.png)
#
# In this task you have to implement a simple one-layer RNN as a class in Pytorch, where you can choose a relu or tanh activation in the cell.You can see the architecture of a simple RNN in the figure below.
#
#
# <img src=http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/LSTM3-SimpleRNN.png width="600">

# %%
# ToDo: Implement the RNN class
from exercise_code.rnn.rnn_nn import RNN

# %% [markdown]
# Luckily, Pytorch already has implemented a simple RNN in their library and you can call the RNN with <code>nn.RNN</code>. We will use the Pytorch RNN function to check if we have built the correct cell and compare the output of both functions. We also compare the running time of both classes.

# %%
import torch.nn as nn
import timeit

# choose your network parameters
input_size = 3
hidden_dim = 3
seq_len = 10 

# define the two models
pytorch_rnn=nn.RNN(input_size, hidden_dim)
i2dl_rnn=RNN(input_size, hidden_dim)

# initialise both rnn with same values
for p in pytorch_rnn.parameters():
    nn.init.constant_(p, val=0.3)
for p in i2dl_rnn.parameters():
    nn.init.constant_(p, val=0.3)
    
X=torch.randn(seq_len, 1, input_size)

output_pytorch, h_pytorch = pytorch_rnn(X)
output_i2dl, h_i2dl = i2dl_rnn(X)


# The difference of outputs should be 0!!

diff = torch.sum((output_pytorch-output_i2dl) ** 2)
print("Differnce between pytorch and your RNN implementation: %s" % diff.item())
if diff.item() < 10 ** -10:
    print("Cool, you implemented a correct model.")
else:
    print("Upps! There is something wrong in your model. Try again!")
# Out:
# Differnce between pytorch and your RNN implementation: 0.0
# Cool, you implemented a correct model.

# %%
import timeit
runs=10 ** 4

print("Time Pytorch RNN {} runs: {:.3f}s".format(runs, timeit.timeit("pytorch_rnn(X)", 
                                       setup="from __main__ import pytorch_rnn, X", 
                                       number=runs))
     )

print("Time I2DL RNN {} run: {:.3f}s".format(runs, timeit.timeit("i2dl_rnn(X)", 
                                       setup="from __main__ import i2dl_rnn, X", 
                                       number=runs))
     )
# Out:
# Time Pytorch RNN 10000 runs: 2.221s
# Time I2DL RNN 10000 run: 7.851s

# %% [markdown]
# From now on we will use the Pytorch module that is faster and optimised in performance. However, it is always a good exercise to build the functions by yourself and we really advice you to do the exercise!

# %% [markdown]
# ## Vanishing Gradient
#
# As discussed in the lecture, the simple RNN suffers from vanishing gradients in the backpropagation. The hidden state is manipulated in every time step along the sequence and the effect of the past inputs to the final output vanishes with the distance in time. In the next cell we will explore the vanishing effect of previous inputs in the RNN.

# %%
############################################################################
# TODO: Define a RNN and explore the gradients on the output h_T wrt. the  #
# input at time t and plot your result. What behaviour do you observe?     #
# Hints:                                                                   #
#   - use one input feature                                                #
#   - pytorch allows backward() pass wrt. to any vector                    #
#   - backward() can only be applied to scalars and not to output tensors  #
#   - choose a good representation of the gradient plot                    #
############################################################################
 
input_size=1
hidden_dim=150 # many hidden layers to get vanishing gradients
seq_len= 20

# Define model and calculate result
rnn=nn.RNN(input_size, hidden_dim)
X=torch.randn(seq_len, 1, input_size, requires_grad=True)
_, h_T = rnn(X) # last hidden layer for prediction

# backward pass
h_T_mean = h_T.mean()
h_T_mean.backward()

plt.plot(np.abs(X.grad.numpy().reshape((-1))))
plt.yscale('log')

#X.grad.zero_()
    
############################################################################
#                             END OF YOUR CODE                             #
############################################################################

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Note</h3>
#     <p>It can be seen that the gradient of the output at time t wrt. to a previous input decreases exponentially. Hence, the final output does not change significantly for changes in the previous input and hence the RNN does not have memory.</p>
# <h3>Question</h3>
# <p>In order to better understand the vanishing gradient problem, calculate the gradients
# dh_t/dV, dh_t /dW, and dh_t/dX_0 analytically for t=3 and h_0=0 using Eq. 1. This exercise might seem a little bit tedious but it is really useful. Can you explain the vanishing gradient mathematically based on your findings?</p>
# </div>

# %% [markdown]
# ## Long-Short Term Memory Network (LSTM)
# The vanishing gradient problem had been known for some time until Schmidhuber (1997) developed the Long-Short Term Memory Network and showed that this architecture can overcome the problem. <br>
# A LSTM is a more advanced recurrent network architecture that is able to learn long time dependencies. The architecture of a LSTM is composed of a forget, input, and output gate and the cell can remember values over arbitrary time intervals. Despite various different and exotic LSTM architectures, the standard LSTM cell is shwon in the figure below:
#
#
# <img src=http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/LSTM3-chain.png width="600">

# %% [markdown]
# Compared to a simple RNN the LSTM cell has a hidden vector and an additional cell state vector. __What size does the cell state have?__ <br>
# The operations inside the LSTM are given as
#
# <img src=https://wikimedia.org/api/rest_v1/media/math/render/svg/2db2cba6a0d878e13932fa27ce6f3fb71ad99cf1  width="600">
# where
# f_t: forget gate,  <br>
# i_t: input gate, <br>
# o_t: output gate, <br>
# h_t: hidden state vector, <br>
# c_t: cell state vector, <br>
# x_t: input vector, <br>
# t is time step,
# <br>
# <br>
# and<br>
# sigma_g: sigmoid activation <br>
# sigma_c and sigma_h: hyperbolic tangent function

# %% [markdown]
# In the next step you should implement your own LSTM with the operations stated above.

# %%
# ToDo: Implement the RNN class
from exercise_code.rnn.rnn_nn import LSTM

# %%
# choose your input parameters
input_size = 3
hidden_dim = 3
seq_len = 10 

# define the two models
pytorch_lstm=nn.LSTM(input_size, hidden_dim)
i2dl_lstm=LSTM(input_size, hidden_dim)

# initialise both lstms with same values
for p in pytorch_lstm.parameters():
    nn.init.constant_(p, val=0.3)
for p in i2dl_lstm.parameters():
    nn.init.constant_(p, val=0.3)
    
X=torch.randn(seq_len, 1, input_size)

output_pytorch, (h_pytorch, _) = pytorch_lstm(X)
output_i2dl , (h_i2dl, _ )= i2dl_lstm(X)

# The difference of outputs should be 0!!
diff = torch.sum((output_pytorch-output_i2dl) ** 2)
print("Differnce between pytorch and your RNN implementation: %s" % diff.item())
if diff.item() < 10 ** -10:
    print("Cool, you implemented a correct model.")
else:
    print("Upps! There is something wrong in your model. Try again!")
# Out:
# Differnce between pytorch and your RNN implementation: 0.0
# Cool, you implemented a correct model.

# %%
import timeit
runs=10 ** 4

print("Time Pytorch LSTM {} runs: {:.3f}s".format(runs, timeit.timeit("pytorch_lstm(X)", 
                                       setup="from __main__ import pytorch_lstm, X", 
                                       number=runs))
     )

print("Time I2DL LSTM {} runs: {:.3f}s".format(runs, timeit.timeit("i2dl_lstm(X)", 
                                       setup="from __main__ import i2dl_lstm, X", 
                                       number=runs))
     )
# Out:
# Time Pytorch LSTM 10000 runs: 5.407s
# Time I2DL LSTM 10000 runs: 28.713s

# %% [markdown]
# ## Explore Gradients
# Analogously to the RNN, calculate the gradients of the input wrt. to the output of the LSTM and compare it against the RNN gradients. __What do you see?__

# %%
############################################################################
# TODO: Define a RNN and LSTM and explore the gradients on the output h_T   #
# wrt. the input at time t and plot your result.                           #
############################################################################

# same as for rnn?
# output of forward pass is different!

input_size=1
hidden_dim=150 # many hidden layers to get vanishing gradients
seq_len= 20 

# Define model and calculate result
lstm=nn.LSTM(input_size, hidden_dim)
X=torch.randn(seq_len, 1, input_size, requires_grad=True)
_, (h_T, _) = lstm(X) # last hidden layer for prediction

# backward pass
h_T_mean = h_T.mean()
h_T_mean.backward()

plt.plot(np.abs(X.grad.numpy().reshape((-1))))
plt.yscale('log')

# X.grad.zero_()

############################################################################
#                             END OF YOUR CODE                             #
############################################################################

# %% [markdown]
# ## MNIST image classification with RNNs
#
# In the previous exercises we already have classified images with a Fully Connected and Convolutional Network. In this exercise, we will solve the problem of image classification with a recurrent neural network.
#
# For the experiment we use the MNIST handwritten digits dataset which we already know from the autoencoder exercise. This dataset consists of images of the 10 different digits (10 classes). The images have the resolution 28 x 28. The idea for the RNN classifier is to interpret the image as a sequence of rows. This means that we pass the rows through the RNN and use the final hidden state for classification.

# %% [markdown]
# <div class="alert alert-info">
#     <h3>Note</h3>
#     <p>
#     In this semester you have seen three different types of neural networks, namely Multi-Layer Perceptrons (MLPs), Convolutional Neural Networks (CNNs), and now Recurrent Neural Networks (RNNs). We have seen that we can use all three architectures for image classification. However, it turned out that some models are better than others for image classification. Try to think about advantages and disadvantages of the models, regarding # of parameters, transformations of the object in the image (scaling, rotation, translation,...), training time, testing time, over-fitting, etc.

# %%
# Define data loader
from torchvision import transforms
import pickle

class Unsqueeze(object):
    """Adds a channel dimension that that our 2 dimensional input (H, W), 
    fits the 3 dimensional (H, W, C) expectations of pytorch's ToTensor function which
    expects a PIL image. This is very inefficient but you most probably will use pytorch's
    PIL image loader. Check out the documentation and make it more efficient :)
    """
    def __init__(self, dimension=0):
        self.dimension = dimension
    def __call__(self, numpy_array):
        extended_array = np.expand_dims(numpy_array, self.dimension)
        return extended_array
    def __repr__(self):
        return self.__class__.__name__ + 'dimension={}'.format(dimension)

    
# transformation of data
transform = transforms.Compose([
    Unsqueeze(dimension=3),     
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])


class MnistDataset(torch.utils.data.Dataset):
    def __init__(self, images, labels, 
                 transform=None):
        super(MnistDataset, self).__init__()
        self.images = images
        self.labels = labels
        self.transform = transform
       
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]
        if self.transform: 
            image = self.transform(image)
        return image, label

    
# loading the train data
with open("../datasets/mnist/mnist_train.p", "rb") as f:
    mnist_raw = pickle.load(f)

X, y = mnist_raw
############################################################################
# TODO: Set a useful training/ validation split                            #
############################################################################    

train_split = 0.7

############################################################################
#                             END OF YOUR CODE                             #
############################################################################


train_dset = MnistDataset(X[:int(len(X) * train_split)], y[:int(len(X) * train_split)], transform=transform)
val_dset = MnistDataset(X[int(len(X) * train_split):], y[int(len(X) * train_split):], transform=transform)

# %%
# Visualize some examples from the dataset. Stolen from other notebooks
# We show a few examples of training images from each class.
X=train_dset.images
y=train_dset.labels


classes = list(range(10))
num_classes = len(classes)
samples_per_class = 5
for y_hat, cls in enumerate(classes):
    idxs = np.flatnonzero(train_dset.labels == y_hat)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y_hat + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X[idx])
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %% [markdown]
# Build a classifier based on a RNN where you sequentially feed the rows in the network and use the final hidden state for prediction.

# %% [markdown]
# <img src=https://cdn-images-1.medium.com/max/800/1*Cm_c-I02rBa1rtLZXBhNUw.png width="600">

# %%
from exercise_code.rnn.rnn_nn import LSTM_Classifier, RNN_Classifier
model_rnn = RNN_Classifier()

# %%
from exercise_code.rnn.solver import Solver

# %%
batch_size = 32
train_loader = torch.utils.data.DataLoader(
                 dataset=train_dset,
                 batch_size=batch_size,
                 shuffle=True)
val_loader = torch.utils.data.DataLoader(
                dataset=val_dset,
                batch_size=batch_size,
                shuffle=False)

solver = Solver(optim_args={"lr": 1e-3})

# train rnn model
solver.train(model_rnn, train_loader, val_loader, log_nth=50, num_epochs=10)
# Out:
# START TRAIN.
# /home/moritz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
# [Iteration 50/13130] TRAIN loss: 2.281
# [Iteration 100/13130] TRAIN loss: 2.185
# [Iteration 150/13130] TRAIN loss: 2.121
# [Iteration 200/13130] TRAIN loss: 2.012
# [Iteration 250/13130] TRAIN loss: 1.946
# [Iteration 300/13130] TRAIN loss: 1.900
# [Iteration 350/13130] TRAIN loss: 1.866
# [Iteration 400/13130] TRAIN loss: 1.861
# [Iteration 450/13130] TRAIN loss: 1.829
# [Iteration 500/13130] TRAIN loss: 1.795
# [Iteration 550/13130] TRAIN loss: 1.809
# [Iteration 600/13130] TRAIN loss: 1.776
# [Iteration 650/13130] TRAIN loss: 1.781
# [Iteration 700/13130] TRAIN loss: 1.806
# [Iteration 750/13130] TRAIN loss: 1.743
# [Iteration 800/13130] TRAIN loss: 1.721
# [Iteration 850/13130] TRAIN loss: 1.814
# [Iteration 900/13130] TRAIN loss: 1.759
# [Iteration 950/13130] TRAIN loss: 1.759
# [Iteration 1000/13130] TRAIN loss: 1.748
# [Iteration 1050/13130] TRAIN loss: 1.727
# [Iteration 1100/13130] TRAIN loss: 1.742
# [Iteration 1150/13130] TRAIN loss: 1.769
# [Iteration 1200/13130] TRAIN loss: 1.734
# [Iteration 1250/13130] TRAIN loss: 1.750
# [Iteration 1300/13130] TRAIN loss: 1.713
# [Epoch 1/10] TRAIN acc/loss: 0.500/1.713
# [Epoch 1/10] VAL   acc/loss: 0.572/1.896
# [Iteration 1363/13130] TRAIN loss: 1.731
# [Iteration 1413/13130] TRAIN loss: 1.703
# [Iteration 1463/13130] TRAIN loss: 1.718
# [Iteration 1513/13130] TRAIN loss: 1.693
# [Iteration 1563/13130] TRAIN loss: 1.686
# [Iteration 1613/13130] TRAIN loss: 1.778
# [Iteration 1663/13130] TRAIN loss: 1.710
# [Iteration 1713/13130] TRAIN loss: 1.698
# [Iteration 1763/13130] TRAIN loss: 1.672
# [Iteration 1813/13130] TRAIN loss: 1.692
# [Iteration 1863/13130] TRAIN loss: 1.678
# [Iteration 1913/13130] TRAIN loss: 1.670
# [Iteration 1963/13130] TRAIN loss: 1.710
# [Iteration 2013/13130] TRAIN loss: 1.682
# [Iteration 2063/13130] TRAIN loss: 1.675
# [Iteration 2113/13130] TRAIN loss: 1.731
# [Iteration 2163/13130] TRAIN loss: 1.712
# [Iteration 2213/13130] TRAIN loss: 1.703
# [Iteration 2263/13130] TRAIN loss: 1.733
# [Iteration 2313/13130] TRAIN loss: 1.713
# [Iteration 2363/13130] TRAIN loss: 1.678
# [Iteration 2413/13130] TRAIN loss: 1.697
# [Iteration 2463/13130] TRAIN loss: 1.666
# [Iteration 2513/13130] TRAIN loss: 1.671
# [Iteration 2563/13130] TRAIN loss: 1.700
# [Iteration 2613/13130] TRAIN loss: 1.721
# [Epoch 2/10] TRAIN acc/loss: 0.688/1.721
# [Epoch 2/10] VAL   acc/loss: 0.785/1.678
# [Iteration 2676/13130] TRAIN loss: 1.687
# [Iteration 2726/13130] TRAIN loss: 1.688
# [Iteration 2776/13130] TRAIN loss: 1.693
# [Iteration 2826/13130] TRAIN loss: 1.674
# [Iteration 2876/13130] TRAIN loss: 1.663
# [Iteration 2926/13130] TRAIN loss: 1.661
# [Iteration 2976/13130] TRAIN loss: 1.677
# [Iteration 3026/13130] TRAIN loss: 1.680
# [Iteration 3076/13130] TRAIN loss: 1.678
# [Iteration 3126/13130] TRAIN loss: 1.670
# [Iteration 3176/13130] TRAIN loss: 1.694
# [Iteration 3226/13130] TRAIN loss: 1.655
# [Iteration 3276/13130] TRAIN loss: 1.664
# [Iteration 3326/13130] TRAIN loss: 1.679
# [Iteration 3376/13130] TRAIN loss: 1.653
# [Iteration 3426/13130] TRAIN loss: 1.667
# [Iteration 3476/13130] TRAIN loss: 1.652
# [Iteration 3526/13130] TRAIN loss: 1.653
# [Iteration 3576/13130] TRAIN loss: 1.655
# [Iteration 3626/13130] TRAIN loss: 1.658
# [Iteration 3676/13130] TRAIN loss: 1.652
# [Iteration 3726/13130] TRAIN loss: 1.650
# [Iteration 3776/13130] TRAIN loss: 1.663
# [Iteration 3826/13130] TRAIN loss: 1.652
# [Iteration 3876/13130] TRAIN loss: 1.645
# [Iteration 3926/13130] TRAIN loss: 1.673
# [Epoch 3/10] TRAIN acc/loss: 0.688/1.673
# [Epoch 3/10] VAL   acc/loss: 0.817/1.645
# [Iteration 3989/13130] TRAIN loss: 1.635
# [Iteration 4039/13130] TRAIN loss: 1.736
# [Iteration 4089/13130] TRAIN loss: 1.717
# [Iteration 4139/13130] TRAIN loss: 1.660
# [Iteration 4189/13130] TRAIN loss: 1.661
# [Iteration 4239/13130] TRAIN loss: 1.670
# [Iteration 4289/13130] TRAIN loss: 1.634
# [Iteration 4339/13130] TRAIN loss: 1.640
# [Iteration 4389/13130] TRAIN loss: 1.653
# [Iteration 4439/13130] TRAIN loss: 1.651
# [Iteration 4489/13130] TRAIN loss: 1.666
# [Iteration 4539/13130] TRAIN loss: 1.697
# [Iteration 4589/13130] TRAIN loss: 1.698
# [Iteration 4639/13130] TRAIN loss: 1.657
# [Iteration 4689/13130] TRAIN loss: 1.693
# [Iteration 4739/13130] TRAIN loss: 1.691
# [Iteration 4789/13130] TRAIN loss: 1.668
# [Iteration 4839/13130] TRAIN loss: 1.670
# [Iteration 4889/13130] TRAIN loss: 1.700
# [Iteration 4939/13130] TRAIN loss: 1.661
# [Iteration 4989/13130] TRAIN loss: 1.662
# [Iteration 5039/13130] TRAIN loss: 1.638
# [Iteration 5089/13130] TRAIN loss: 1.633
# [Iteration 5139/13130] TRAIN loss: 1.641
# [Iteration 5189/13130] TRAIN loss: 1.638
# [Iteration 5239/13130] TRAIN loss: 1.666
# [Epoch 4/10] TRAIN acc/loss: 0.938/1.666
# [Epoch 4/10] VAL   acc/loss: 0.813/1.649
# [Iteration 5302/13130] TRAIN loss: 1.644
# [Iteration 5352/13130] TRAIN loss: 1.663
# [Iteration 5402/13130] TRAIN loss: 1.722
# [Iteration 5452/13130] TRAIN loss: 1.657
# [Iteration 5502/13130] TRAIN loss: 1.651
# [Iteration 5552/13130] TRAIN loss: 1.642
# [Iteration 5602/13130] TRAIN loss: 1.647
# [Iteration 5652/13130] TRAIN loss: 1.633
# [Iteration 5702/13130] TRAIN loss: 1.647
# [Iteration 5752/13130] TRAIN loss: 1.678
# [Iteration 5802/13130] TRAIN loss: 1.661
# [Iteration 5852/13130] TRAIN loss: 1.652
# [Iteration 5902/13130] TRAIN loss: 1.648
# [Iteration 5952/13130] TRAIN loss: 1.637
# [Iteration 6002/13130] TRAIN loss: 1.656
# [Iteration 6052/13130] TRAIN loss: 1.633
# [Iteration 6102/13130] TRAIN loss: 1.746
# [Iteration 6152/13130] TRAIN loss: 1.738
# [Iteration 6202/13130] TRAIN loss: 1.655
# [Iteration 6252/13130] TRAIN loss: 1.673
# [Iteration 6302/13130] TRAIN loss: 1.721
# [Iteration 6352/13130] TRAIN loss: 1.676
# [Iteration 6402/13130] TRAIN loss: 1.632
# [Iteration 6452/13130] TRAIN loss: 1.667
# [Iteration 6502/13130] TRAIN loss: 1.634
# [Iteration 6552/13130] TRAIN loss: 1.679
# [Epoch 5/10] TRAIN acc/loss: 0.500/1.679
# [Epoch 5/10] VAL   acc/loss: 0.705/1.758
# [Iteration 6615/13130] TRAIN loss: 1.694
# [Iteration 6665/13130] TRAIN loss: 1.702
# [Iteration 6715/13130] TRAIN loss: 1.691
# [Iteration 6765/13130] TRAIN loss: 1.655
# [Iteration 6815/13130] TRAIN loss: 1.658
# [Iteration 6865/13130] TRAIN loss: 1.658
# [Iteration 6915/13130] TRAIN loss: 1.661
# [Iteration 6965/13130] TRAIN loss: 1.657
# [Iteration 7015/13130] TRAIN loss: 1.651
# [Iteration 7065/13130] TRAIN loss: 1.642
# [Iteration 7115/13130] TRAIN loss: 1.628
# [Iteration 7165/13130] TRAIN loss: 1.621
# [Iteration 7215/13130] TRAIN loss: 1.637
# [Iteration 7265/13130] TRAIN loss: 1.678
# [Iteration 7315/13130] TRAIN loss: 1.671
# [Iteration 7365/13130] TRAIN loss: 1.641
# [Iteration 7415/13130] TRAIN loss: 1.613
# [Iteration 7465/13130] TRAIN loss: 1.636
# [Iteration 7515/13130] TRAIN loss: 1.637
# [Iteration 7565/13130] TRAIN loss: 1.635
# [Iteration 7615/13130] TRAIN loss: 1.621
# [Iteration 7665/13130] TRAIN loss: 1.653
# [Iteration 7715/13130] TRAIN loss: 1.654
# [Iteration 7765/13130] TRAIN loss: 1.633
# [Iteration 7815/13130] TRAIN loss: 1.622
# [Iteration 7865/13130] TRAIN loss: 1.640
# [Epoch 6/10] TRAIN acc/loss: 0.750/1.640
# [Epoch 6/10] VAL   acc/loss: 0.794/1.670
# [Iteration 7928/13130] TRAIN loss: 1.634
# [Iteration 7978/13130] TRAIN loss: 1.632
# [Iteration 8028/13130] TRAIN loss: 1.632
# [Iteration 8078/13130] TRAIN loss: 1.631
# [Iteration 8128/13130] TRAIN loss: 1.669
# [Iteration 8178/13130] TRAIN loss: 1.650
# [Iteration 8228/13130] TRAIN loss: 1.630
# [Iteration 8278/13130] TRAIN loss: 1.635
# [Iteration 8328/13130] TRAIN loss: 1.621
# [Iteration 8378/13130] TRAIN loss: 1.642
# [Iteration 8428/13130] TRAIN loss: 1.653
# [Iteration 8478/13130] TRAIN loss: 1.661
# [Iteration 8528/13130] TRAIN loss: 1.667
# [Iteration 8578/13130] TRAIN loss: 1.642
# [Iteration 8628/13130] TRAIN loss: 1.648
# [Iteration 8678/13130] TRAIN loss: 1.639
# [Iteration 8728/13130] TRAIN loss: 1.630
# [Iteration 8778/13130] TRAIN loss: 1.664
# [Iteration 8828/13130] TRAIN loss: 1.639
# [Iteration 8878/13130] TRAIN loss: 1.716
# [Iteration 8928/13130] TRAIN loss: 1.685
# [Iteration 8978/13130] TRAIN loss: 1.654
# [Iteration 9028/13130] TRAIN loss: 1.639
# [Iteration 9078/13130] TRAIN loss: 1.687
# [Iteration 9128/13130] TRAIN loss: 1.660
# [Iteration 9178/13130] TRAIN loss: 1.702
# [Epoch 7/10] TRAIN acc/loss: 0.688/1.702
# [Epoch 7/10] VAL   acc/loss: 0.801/1.661
# [Iteration 9241/13130] TRAIN loss: 1.659
# [Iteration 9291/13130] TRAIN loss: 1.649
# [Iteration 9341/13130] TRAIN loss: 1.652
# [Iteration 9391/13130] TRAIN loss: 1.633
# [Iteration 9441/13130] TRAIN loss: 1.649
# [Iteration 9491/13130] TRAIN loss: 1.637
# [Iteration 9541/13130] TRAIN loss: 1.644
# [Iteration 9591/13130] TRAIN loss: 1.594
# [Iteration 9641/13130] TRAIN loss: 1.625
# [Iteration 9691/13130] TRAIN loss: 1.632
# [Iteration 9741/13130] TRAIN loss: 1.626
# [Iteration 9791/13130] TRAIN loss: 1.632
# [Iteration 9841/13130] TRAIN loss: 1.626
# [Iteration 9891/13130] TRAIN loss: 1.606
# [Iteration 9941/13130] TRAIN loss: 1.611
# [Iteration 9991/13130] TRAIN loss: 1.603
# [Iteration 10041/13130] TRAIN loss: 1.602
# [Iteration 10091/13130] TRAIN loss: 1.592
# [Iteration 10141/13130] TRAIN loss: 1.580
# [Iteration 10191/13130] TRAIN loss: 1.596
# [Iteration 10241/13130] TRAIN loss: 1.641
# [Iteration 10291/13130] TRAIN loss: 1.635
# [Iteration 10341/13130] TRAIN loss: 1.611
# [Iteration 10391/13130] TRAIN loss: 1.587
# [Iteration 10441/13130] TRAIN loss: 1.618
# [Iteration 10491/13130] TRAIN loss: 1.572
# [Epoch 8/10] TRAIN acc/loss: 0.750/1.572
# [Epoch 8/10] VAL   acc/loss: 0.833/1.632
# [Iteration 10554/13130] TRAIN loss: 1.649
# [Iteration 10604/13130] TRAIN loss: 1.617
# [Iteration 10654/13130] TRAIN loss: 1.568
# [Iteration 10704/13130] TRAIN loss: 1.597
# [Iteration 10754/13130] TRAIN loss: 1.589
# [Iteration 10804/13130] TRAIN loss: 1.592
# [Iteration 10854/13130] TRAIN loss: 1.585
# [Iteration 10904/13130] TRAIN loss: 1.575
# [Iteration 10954/13130] TRAIN loss: 1.595
# [Iteration 11004/13130] TRAIN loss: 1.579
# [Iteration 11054/13130] TRAIN loss: 1.570
# [Iteration 11104/13130] TRAIN loss: 1.571
# [Iteration 11154/13130] TRAIN loss: 1.577
# [Iteration 11204/13130] TRAIN loss: 1.559
# [Iteration 11254/13130] TRAIN loss: 1.556
# [Iteration 11304/13130] TRAIN loss: 1.587
# [Iteration 11354/13130] TRAIN loss: 1.615
# [Iteration 11404/13130] TRAIN loss: 1.581
# [Iteration 11454/13130] TRAIN loss: 1.571
# [Iteration 11504/13130] TRAIN loss: 1.586
# [Iteration 11554/13130] TRAIN loss: 1.570
# [Iteration 11604/13130] TRAIN loss: 1.668
# [Iteration 11654/13130] TRAIN loss: 1.595
# [Iteration 11704/13130] TRAIN loss: 1.609
# [Iteration 11754/13130] TRAIN loss: 1.591
# [Iteration 11804/13130] TRAIN loss: 1.602
# [Epoch 9/10] TRAIN acc/loss: 0.875/1.602
# [Epoch 9/10] VAL   acc/loss: 0.857/1.605
# [Iteration 11867/13130] TRAIN loss: 1.591
# [Iteration 11917/13130] TRAIN loss: 1.591
# [Iteration 11967/13130] TRAIN loss: 1.587
# [Iteration 12017/13130] TRAIN loss: 1.589
# [Iteration 12067/13130] TRAIN loss: 1.567
# [Iteration 12117/13130] TRAIN loss: 1.568
# [Iteration 12167/13130] TRAIN loss: 1.558
# [Iteration 12217/13130] TRAIN loss: 1.573
# [Iteration 12267/13130] TRAIN loss: 1.577
# [Iteration 12317/13130] TRAIN loss: 1.585
# [Iteration 12367/13130] TRAIN loss: 1.568
# [Iteration 12417/13130] TRAIN loss: 1.606
# [Iteration 12467/13130] TRAIN loss: 1.568
# [Iteration 12517/13130] TRAIN loss: 1.590
# [Iteration 12567/13130] TRAIN loss: 1.611
# [Iteration 12617/13130] TRAIN loss: 1.593
# [Iteration 12667/13130] TRAIN loss: 1.566
# [Iteration 12717/13130] TRAIN loss: 1.604
# [Iteration 12767/13130] TRAIN loss: 1.619
# [Iteration 12817/13130] TRAIN loss: 1.573
# [Iteration 12867/13130] TRAIN loss: 1.600
# [Iteration 12917/13130] TRAIN loss: 1.620
# [Iteration 12967/13130] TRAIN loss: 1.570
# [Iteration 13017/13130] TRAIN loss: 1.571
# [Iteration 13067/13130] TRAIN loss: 1.562
# [Iteration 13117/13130] TRAIN loss: 1.590
# [Epoch 10/10] TRAIN acc/loss: 0.938/1.590
# [Epoch 10/10] VAL   acc/loss: 0.891/1.571
# FINISH.

# %% [markdown]
# Train your RNN classifier and try to tune the hyperparameters. With your simple RNN classifier you should exceed an accuracy higher than __90%__.

# %% [markdown]
# Try to improve your model by using a LSTM.

# %%
from exercise_code.rnn.rnn_nn import LSTM_Classifier
model_lstm = LSTM_Classifier()

# %% [markdown]
# Train your LSTM model again and see wether it improves performance on the validation set

# %%
from exercise_code.rnn.solver import Solver

# %%
batch_size = 32
train_loader = torch.utils.data.DataLoader(
                 dataset=train_dset,
                 batch_size=batch_size,
                 shuffle=True)
val_loader = torch.utils.data.DataLoader(
                dataset=val_dset,
                batch_size=batch_size,
                shuffle=False)

solver = Solver(optim_args={"lr": 1e-3})

# train lstm model
solver.train(model_lstm, train_loader, val_loader, log_nth=50, num_epochs=15)
# Out:
# START TRAIN.
# /home/moritz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
# [Iteration 50/19695] TRAIN loss: 2.279
# [Iteration 100/19695] TRAIN loss: 2.086
# [Iteration 150/19695] TRAIN loss: 1.945
# [Iteration 200/19695] TRAIN loss: 1.896
# [Iteration 250/19695] TRAIN loss: 1.839
# [Iteration 300/19695] TRAIN loss: 1.773
# [Iteration 350/19695] TRAIN loss: 1.698
# [Iteration 400/19695] TRAIN loss: 1.676
# [Iteration 450/19695] TRAIN loss: 1.636
# [Iteration 500/19695] TRAIN loss: 1.647
# [Iteration 550/19695] TRAIN loss: 1.591
# [Iteration 600/19695] TRAIN loss: 1.587
# [Iteration 650/19695] TRAIN loss: 1.591
# [Iteration 700/19695] TRAIN loss: 1.559
# [Iteration 750/19695] TRAIN loss: 1.578
# [Iteration 800/19695] TRAIN loss: 1.572
# [Iteration 850/19695] TRAIN loss: 1.557
# [Iteration 900/19695] TRAIN loss: 1.556
# [Iteration 950/19695] TRAIN loss: 1.571
# [Iteration 1000/19695] TRAIN loss: 1.576
# [Iteration 1050/19695] TRAIN loss: 1.533
# [Iteration 1100/19695] TRAIN loss: 1.535
# [Iteration 1150/19695] TRAIN loss: 1.556
# [Iteration 1200/19695] TRAIN loss: 1.542
# [Iteration 1250/19695] TRAIN loss: 1.523
# [Iteration 1300/19695] TRAIN loss: 1.524
# [Epoch 1/15] TRAIN acc/loss: 0.938/1.524
# [Epoch 1/15] VAL   acc/loss: 0.932/1.534
# [Iteration 1363/19695] TRAIN loss: 1.534
# [Iteration 1413/19695] TRAIN loss: 1.534
# [Iteration 1463/19695] TRAIN loss: 1.516
# [Iteration 1513/19695] TRAIN loss: 1.532
# [Iteration 1563/19695] TRAIN loss: 1.537
# [Iteration 1613/19695] TRAIN loss: 1.517
# [Iteration 1663/19695] TRAIN loss: 1.518
# [Iteration 1713/19695] TRAIN loss: 1.516
# [Iteration 1763/19695] TRAIN loss: 1.517
# [Iteration 1813/19695] TRAIN loss: 1.518
# [Iteration 1863/19695] TRAIN loss: 1.517
# [Iteration 1913/19695] TRAIN loss: 1.523
# [Iteration 1963/19695] TRAIN loss: 1.513
# [Iteration 2013/19695] TRAIN loss: 1.515
# [Iteration 2063/19695] TRAIN loss: 1.520
# [Iteration 2113/19695] TRAIN loss: 1.529
# [Iteration 2163/19695] TRAIN loss: 1.506
# [Iteration 2213/19695] TRAIN loss: 1.528
# [Iteration 2263/19695] TRAIN loss: 1.536
# [Iteration 2313/19695] TRAIN loss: 1.522
# [Iteration 2363/19695] TRAIN loss: 1.508
# [Iteration 2413/19695] TRAIN loss: 1.511
# [Iteration 2463/19695] TRAIN loss: 1.525
# [Iteration 2513/19695] TRAIN loss: 1.519
# [Iteration 2563/19695] TRAIN loss: 1.523
# [Iteration 2613/19695] TRAIN loss: 1.506
# [Epoch 2/15] TRAIN acc/loss: 0.938/1.506
# [Epoch 2/15] VAL   acc/loss: 0.953/1.509
# [Iteration 2676/19695] TRAIN loss: 1.503
# [Iteration 2726/19695] TRAIN loss: 1.491
# [Iteration 2776/19695] TRAIN loss: 1.503
# [Iteration 2826/19695] TRAIN loss: 1.508
# [Iteration 2876/19695] TRAIN loss: 1.499
# [Iteration 2926/19695] TRAIN loss: 1.501
# [Iteration 2976/19695] TRAIN loss: 1.499
# [Iteration 3026/19695] TRAIN loss: 1.502
# [Iteration 3076/19695] TRAIN loss: 1.506
# [Iteration 3126/19695] TRAIN loss: 1.498
# [Iteration 3176/19695] TRAIN loss: 1.507
# [Iteration 3226/19695] TRAIN loss: 1.503
# [Iteration 3276/19695] TRAIN loss: 1.505
# [Iteration 3326/19695] TRAIN loss: 1.500
# [Iteration 3376/19695] TRAIN loss: 1.505
# [Iteration 3426/19695] TRAIN loss: 1.518
# [Iteration 3476/19695] TRAIN loss: 1.500
# [Iteration 3526/19695] TRAIN loss: 1.501
# [Iteration 3576/19695] TRAIN loss: 1.507
# [Iteration 3626/19695] TRAIN loss: 1.501
# [Iteration 3676/19695] TRAIN loss: 1.496
# [Iteration 3726/19695] TRAIN loss: 1.502
# [Iteration 3776/19695] TRAIN loss: 1.506
# [Iteration 3826/19695] TRAIN loss: 1.505
# [Iteration 3876/19695] TRAIN loss: 1.503
# [Iteration 3926/19695] TRAIN loss: 1.498
# [Epoch 3/15] TRAIN acc/loss: 1.000/1.498
# [Epoch 3/15] VAL   acc/loss: 0.962/1.500
# [Iteration 3989/19695] TRAIN loss: 1.494
# [Iteration 4039/19695] TRAIN loss: 1.496
# [Iteration 4089/19695] TRAIN loss: 1.498
# [Iteration 4139/19695] TRAIN loss: 1.492
# [Iteration 4189/19695] TRAIN loss: 1.492
# [Iteration 4239/19695] TRAIN loss: 1.491
# [Iteration 4289/19695] TRAIN loss: 1.492
# [Iteration 4339/19695] TRAIN loss: 1.495
# [Iteration 4389/19695] TRAIN loss: 1.495
# [Iteration 4439/19695] TRAIN loss: 1.494
# [Iteration 4489/19695] TRAIN loss: 1.494
# [Iteration 4539/19695] TRAIN loss: 1.489
# [Iteration 4589/19695] TRAIN loss: 1.500
# [Iteration 4639/19695] TRAIN loss: 1.509
# [Iteration 4689/19695] TRAIN loss: 1.510
# [Iteration 4739/19695] TRAIN loss: 1.495
# [Iteration 4789/19695] TRAIN loss: 1.499
# [Iteration 4839/19695] TRAIN loss: 1.504
# [Iteration 4889/19695] TRAIN loss: 1.500
# [Iteration 4939/19695] TRAIN loss: 1.493
# [Iteration 4989/19695] TRAIN loss: 1.504
# [Iteration 5039/19695] TRAIN loss: 1.493
# [Iteration 5089/19695] TRAIN loss: 1.496
# [Iteration 5139/19695] TRAIN loss: 1.504
# [Iteration 5189/19695] TRAIN loss: 1.494
# [Iteration 5239/19695] TRAIN loss: 1.495
# [Epoch 4/15] TRAIN acc/loss: 1.000/1.495
# [Epoch 4/15] VAL   acc/loss: 0.959/1.503
# [Iteration 5302/19695] TRAIN loss: 1.491
# [Iteration 5352/19695] TRAIN loss: 1.490
# [Iteration 5402/19695] TRAIN loss: 1.492
# [Iteration 5452/19695] TRAIN loss: 1.497
# [Iteration 5502/19695] TRAIN loss: 1.500
# [Iteration 5552/19695] TRAIN loss: 1.502
# [Iteration 5602/19695] TRAIN loss: 1.499
# [Iteration 5652/19695] TRAIN loss: 1.487
# [Iteration 5702/19695] TRAIN loss: 1.492
# [Iteration 5752/19695] TRAIN loss: 1.491
# [Iteration 5802/19695] TRAIN loss: 1.496
# [Iteration 5852/19695] TRAIN loss: 1.488
# [Iteration 5902/19695] TRAIN loss: 1.493
# [Iteration 5952/19695] TRAIN loss: 1.485
# [Iteration 6002/19695] TRAIN loss: 1.494
# [Iteration 6052/19695] TRAIN loss: 1.492
# [Iteration 6102/19695] TRAIN loss: 1.494
# [Iteration 6152/19695] TRAIN loss: 1.492
# [Iteration 6202/19695] TRAIN loss: 1.483
# [Iteration 6252/19695] TRAIN loss: 1.480
# [Iteration 6302/19695] TRAIN loss: 1.486
# [Iteration 6352/19695] TRAIN loss: 1.488
# [Iteration 6402/19695] TRAIN loss: 1.486
# [Iteration 6452/19695] TRAIN loss: 1.490
# [Iteration 6502/19695] TRAIN loss: 1.502
# [Iteration 6552/19695] TRAIN loss: 1.500
# [Epoch 5/15] TRAIN acc/loss: 0.875/1.500
# [Epoch 5/15] VAL   acc/loss: 0.966/1.496
# [Iteration 6615/19695] TRAIN loss: 1.487
# [Iteration 6665/19695] TRAIN loss: 1.486
# [Iteration 6715/19695] TRAIN loss: 1.489
# [Iteration 6765/19695] TRAIN loss: 1.490
# [Iteration 6815/19695] TRAIN loss: 1.487
# [Iteration 6865/19695] TRAIN loss: 1.484
# [Iteration 6915/19695] TRAIN loss: 1.478
# [Iteration 6965/19695] TRAIN loss: 1.491
# [Iteration 7015/19695] TRAIN loss: 1.490
# [Iteration 7065/19695] TRAIN loss: 1.483
# [Iteration 7115/19695] TRAIN loss: 1.486
# [Iteration 7165/19695] TRAIN loss: 1.490
# [Iteration 7215/19695] TRAIN loss: 1.491
# [Iteration 7265/19695] TRAIN loss: 1.485
# [Iteration 7315/19695] TRAIN loss: 1.482
# [Iteration 7365/19695] TRAIN loss: 1.498
# [Iteration 7415/19695] TRAIN loss: 1.488
# [Iteration 7465/19695] TRAIN loss: 1.486
# [Iteration 7515/19695] TRAIN loss: 1.492
# [Iteration 7565/19695] TRAIN loss: 1.493
# [Iteration 7615/19695] TRAIN loss: 1.488
# [Iteration 7665/19695] TRAIN loss: 1.490
# [Iteration 7715/19695] TRAIN loss: 1.493
# [Iteration 7765/19695] TRAIN loss: 1.493
# [Iteration 7815/19695] TRAIN loss: 1.488
# [Iteration 7865/19695] TRAIN loss: 1.490
# [Epoch 6/15] TRAIN acc/loss: 1.000/1.490
# [Epoch 6/15] VAL   acc/loss: 0.971/1.491
# [Iteration 7928/19695] TRAIN loss: 1.483
# [Iteration 7978/19695] TRAIN loss: 1.483
# [Iteration 8028/19695] TRAIN loss: 1.488
# [Iteration 8078/19695] TRAIN loss: 1.483
# [Iteration 8128/19695] TRAIN loss: 1.481
# [Iteration 8178/19695] TRAIN loss: 1.495
# [Iteration 8228/19695] TRAIN loss: 1.486
# [Iteration 8278/19695] TRAIN loss: 1.486
# [Iteration 8328/19695] TRAIN loss: 1.482
# [Iteration 8378/19695] TRAIN loss: 1.483
# [Iteration 8428/19695] TRAIN loss: 1.489
# [Iteration 8478/19695] TRAIN loss: 1.486
# [Iteration 8528/19695] TRAIN loss: 1.488
# [Iteration 8578/19695] TRAIN loss: 1.487
# [Iteration 8628/19695] TRAIN loss: 1.492
# [Iteration 8678/19695] TRAIN loss: 1.489
# [Iteration 8728/19695] TRAIN loss: 1.483
# [Iteration 8778/19695] TRAIN loss: 1.482
# [Iteration 8828/19695] TRAIN loss: 1.478
# [Iteration 8878/19695] TRAIN loss: 1.487
# [Iteration 8928/19695] TRAIN loss: 1.481
# [Iteration 8978/19695] TRAIN loss: 1.492
# [Iteration 9028/19695] TRAIN loss: 1.487
# [Iteration 9078/19695] TRAIN loss: 1.487
# [Iteration 9128/19695] TRAIN loss: 1.488
# [Iteration 9178/19695] TRAIN loss: 1.482
# [Epoch 7/15] TRAIN acc/loss: 1.000/1.482
# [Epoch 7/15] VAL   acc/loss: 0.978/1.483
# [Iteration 9241/19695] TRAIN loss: 1.475
# [Iteration 9291/19695] TRAIN loss: 1.480
# [Iteration 9341/19695] TRAIN loss: 1.484
# [Iteration 9391/19695] TRAIN loss: 1.485
# [Iteration 9441/19695] TRAIN loss: 1.479
# [Iteration 9491/19695] TRAIN loss: 1.483
# [Iteration 9541/19695] TRAIN loss: 1.486
# [Iteration 9591/19695] TRAIN loss: 1.485
# [Iteration 9641/19695] TRAIN loss: 1.490
# [Iteration 9691/19695] TRAIN loss: 1.488
# [Iteration 9741/19695] TRAIN loss: 1.484
# [Iteration 9791/19695] TRAIN loss: 1.479
# [Iteration 9841/19695] TRAIN loss: 1.487
# [Iteration 9891/19695] TRAIN loss: 1.489
# [Iteration 9941/19695] TRAIN loss: 1.490
# [Iteration 9991/19695] TRAIN loss: 1.491
# [Iteration 10041/19695] TRAIN loss: 1.483
# [Iteration 10091/19695] TRAIN loss: 1.479
# [Iteration 10141/19695] TRAIN loss: 1.488
# [Iteration 10191/19695] TRAIN loss: 1.496
# [Iteration 10241/19695] TRAIN loss: 1.489
# [Iteration 10291/19695] TRAIN loss: 1.486
# [Iteration 10341/19695] TRAIN loss: 1.482
# [Iteration 10391/19695] TRAIN loss: 1.482
# [Iteration 10441/19695] TRAIN loss: 1.498
# [Iteration 10491/19695] TRAIN loss: 1.485
# [Epoch 8/15] TRAIN acc/loss: 0.938/1.485
# [Epoch 8/15] VAL   acc/loss: 0.980/1.481
# [Iteration 10554/19695] TRAIN loss: 1.488
# [Iteration 10604/19695] TRAIN loss: 1.478
# [Iteration 10654/19695] TRAIN loss: 1.484
# [Iteration 10704/19695] TRAIN loss: 1.478
# [Iteration 10754/19695] TRAIN loss: 1.477
# [Iteration 10804/19695] TRAIN loss: 1.482
# [Iteration 10854/19695] TRAIN loss: 1.486
# [Iteration 10904/19695] TRAIN loss: 1.479
# [Iteration 10954/19695] TRAIN loss: 1.487
# [Iteration 11004/19695] TRAIN loss: 1.486
# [Iteration 11054/19695] TRAIN loss: 1.476
# [Iteration 11104/19695] TRAIN loss: 1.480
# [Iteration 11154/19695] TRAIN loss: 1.487
# [Iteration 11204/19695] TRAIN loss: 1.487
# [Iteration 11254/19695] TRAIN loss: 1.490
# [Iteration 11304/19695] TRAIN loss: 1.491
# [Iteration 11354/19695] TRAIN loss: 1.483
# [Iteration 11404/19695] TRAIN loss: 1.485
# [Iteration 11454/19695] TRAIN loss: 1.485
# [Iteration 11504/19695] TRAIN loss: 1.490
# [Iteration 11554/19695] TRAIN loss: 1.482
# [Iteration 11604/19695] TRAIN loss: 1.488
# [Iteration 11654/19695] TRAIN loss: 1.488
# [Iteration 11704/19695] TRAIN loss: 1.478
# [Iteration 11754/19695] TRAIN loss: 1.483
# [Iteration 11804/19695] TRAIN loss: 1.481
# [Epoch 9/15] TRAIN acc/loss: 1.000/1.481
# [Epoch 9/15] VAL   acc/loss: 0.978/1.484
# [Iteration 11867/19695] TRAIN loss: 1.486
# [Iteration 11917/19695] TRAIN loss: 1.487
# [Iteration 11967/19695] TRAIN loss: 1.476
# [Iteration 12017/19695] TRAIN loss: 1.476
# [Iteration 12067/19695] TRAIN loss: 1.480
# [Iteration 12117/19695] TRAIN loss: 1.480
# [Iteration 12167/19695] TRAIN loss: 1.476
# [Iteration 12217/19695] TRAIN loss: 1.482
# [Iteration 12267/19695] TRAIN loss: 1.483
# [Iteration 12317/19695] TRAIN loss: 1.489
# [Iteration 12367/19695] TRAIN loss: 1.480
# [Iteration 12417/19695] TRAIN loss: 1.478
# [Iteration 12467/19695] TRAIN loss: 1.476
# [Iteration 12517/19695] TRAIN loss: 1.475
# [Iteration 12567/19695] TRAIN loss: 1.485
# [Iteration 12617/19695] TRAIN loss: 1.482
# [Iteration 12667/19695] TRAIN loss: 1.482
# [Iteration 12717/19695] TRAIN loss: 1.491
# [Iteration 12767/19695] TRAIN loss: 1.491
# [Iteration 12817/19695] TRAIN loss: 1.485
# [Iteration 12867/19695] TRAIN loss: 1.488
# [Iteration 12917/19695] TRAIN loss: 1.482
# [Iteration 12967/19695] TRAIN loss: 1.497
# [Iteration 13017/19695] TRAIN loss: 1.486
# [Iteration 13067/19695] TRAIN loss: 1.482
# [Iteration 13117/19695] TRAIN loss: 1.481
# [Epoch 10/15] TRAIN acc/loss: 1.000/1.481
# [Epoch 10/15] VAL   acc/loss: 0.977/1.484
# [Iteration 13180/19695] TRAIN loss: 1.478
# [Iteration 13230/19695] TRAIN loss: 1.484
# [Iteration 13280/19695] TRAIN loss: 1.478
# [Iteration 13330/19695] TRAIN loss: 1.486
# [Iteration 13380/19695] TRAIN loss: 1.478
# [Iteration 13430/19695] TRAIN loss: 1.478
# [Iteration 13480/19695] TRAIN loss: 1.480
# [Iteration 13530/19695] TRAIN loss: 1.484
# [Iteration 13580/19695] TRAIN loss: 1.474
# [Iteration 13630/19695] TRAIN loss: 1.477
# [Iteration 13680/19695] TRAIN loss: 1.479
# [Iteration 13730/19695] TRAIN loss: 1.480
# [Iteration 13780/19695] TRAIN loss: 1.487
# [Iteration 13830/19695] TRAIN loss: 1.478
# [Iteration 13880/19695] TRAIN loss: 1.472
# [Iteration 13930/19695] TRAIN loss: 1.477
# [Iteration 13980/19695] TRAIN loss: 1.483
# [Iteration 14030/19695] TRAIN loss: 1.481
# [Iteration 14080/19695] TRAIN loss: 1.484
# [Iteration 14130/19695] TRAIN loss: 1.480
# [Iteration 14180/19695] TRAIN loss: 1.477
# [Iteration 14230/19695] TRAIN loss: 1.482
# [Iteration 14280/19695] TRAIN loss: 1.478
# [Iteration 14330/19695] TRAIN loss: 1.474
# [Iteration 14380/19695] TRAIN loss: 1.481
# [Iteration 14430/19695] TRAIN loss: 1.480
# [Epoch 11/15] TRAIN acc/loss: 1.000/1.480
# [Epoch 11/15] VAL   acc/loss: 0.981/1.480
# [Iteration 14493/19695] TRAIN loss: 1.481
# [Iteration 14543/19695] TRAIN loss: 1.487
# [Iteration 14593/19695] TRAIN loss: 1.483
# [Iteration 14643/19695] TRAIN loss: 1.481
# [Iteration 14693/19695] TRAIN loss: 1.476
# [Iteration 14743/19695] TRAIN loss: 1.484
# [Iteration 14793/19695] TRAIN loss: 1.478
# [Iteration 14843/19695] TRAIN loss: 1.485
# [Iteration 14893/19695] TRAIN loss: 1.476
# [Iteration 14943/19695] TRAIN loss: 1.478
# [Iteration 14993/19695] TRAIN loss: 1.488
# [Iteration 15043/19695] TRAIN loss: 1.483
# [Iteration 15093/19695] TRAIN loss: 1.482
# [Iteration 15143/19695] TRAIN loss: 1.481
# [Iteration 15193/19695] TRAIN loss: 1.495
# [Iteration 15243/19695] TRAIN loss: 1.492
# [Iteration 15293/19695] TRAIN loss: 1.489
# [Iteration 15343/19695] TRAIN loss: 1.483
# [Iteration 15393/19695] TRAIN loss: 1.480
# [Iteration 15443/19695] TRAIN loss: 1.477
# [Iteration 15493/19695] TRAIN loss: 1.475
# [Iteration 15543/19695] TRAIN loss: 1.478
# [Iteration 15593/19695] TRAIN loss: 1.480
# [Iteration 15643/19695] TRAIN loss: 1.486
# [Iteration 15693/19695] TRAIN loss: 1.474
# [Iteration 15743/19695] TRAIN loss: 1.476
# [Epoch 12/15] TRAIN acc/loss: 1.000/1.476
# [Epoch 12/15] VAL   acc/loss: 0.982/1.480
# [Iteration 15806/19695] TRAIN loss: 1.481
# [Iteration 15856/19695] TRAIN loss: 1.474
# [Iteration 15906/19695] TRAIN loss: 1.477
# [Iteration 15956/19695] TRAIN loss: 1.478
# [Iteration 16006/19695] TRAIN loss: 1.475
# [Iteration 16056/19695] TRAIN loss: 1.476
# [Iteration 16106/19695] TRAIN loss: 1.473
# [Iteration 16156/19695] TRAIN loss: 1.486
# [Iteration 16206/19695] TRAIN loss: 1.471
# [Iteration 16256/19695] TRAIN loss: 1.474
# [Iteration 16306/19695] TRAIN loss: 1.473
# [Iteration 16356/19695] TRAIN loss: 1.478
# [Iteration 16406/19695] TRAIN loss: 1.474
# [Iteration 16456/19695] TRAIN loss: 1.474
# [Iteration 16506/19695] TRAIN loss: 1.475
# [Iteration 16556/19695] TRAIN loss: 1.473
# [Iteration 16606/19695] TRAIN loss: 1.478
# [Iteration 16656/19695] TRAIN loss: 1.477
# [Iteration 16706/19695] TRAIN loss: 1.481
# [Iteration 16756/19695] TRAIN loss: 1.481
# [Iteration 16806/19695] TRAIN loss: 1.480
# [Iteration 16856/19695] TRAIN loss: 1.486
# [Iteration 16906/19695] TRAIN loss: 1.484
# [Iteration 16956/19695] TRAIN loss: 1.479
# [Iteration 17006/19695] TRAIN loss: 1.481
# [Iteration 17056/19695] TRAIN loss: 1.476
# [Epoch 13/15] TRAIN acc/loss: 1.000/1.476
# [Epoch 13/15] VAL   acc/loss: 0.967/1.494
# [Iteration 17119/19695] TRAIN loss: 1.484
# [Iteration 17169/19695] TRAIN loss: 1.475
# [Iteration 17219/19695] TRAIN loss: 1.487
# [Iteration 17269/19695] TRAIN loss: 1.473
# [Iteration 17319/19695] TRAIN loss: 1.478
# [Iteration 17369/19695] TRAIN loss: 1.473
# [Iteration 17419/19695] TRAIN loss: 1.477
# [Iteration 17469/19695] TRAIN loss: 1.477
# [Iteration 17519/19695] TRAIN loss: 1.476
# [Iteration 17569/19695] TRAIN loss: 1.474
# [Iteration 17619/19695] TRAIN loss: 1.475
# [Iteration 17669/19695] TRAIN loss: 1.480
# [Iteration 17719/19695] TRAIN loss: 1.476
# [Iteration 17769/19695] TRAIN loss: 1.471
# [Iteration 17819/19695] TRAIN loss: 1.479
# [Iteration 17869/19695] TRAIN loss: 1.479
# [Iteration 17919/19695] TRAIN loss: 1.475
# [Iteration 17969/19695] TRAIN loss: 1.479
# [Iteration 18019/19695] TRAIN loss: 1.476
# [Iteration 18069/19695] TRAIN loss: 1.476
# [Iteration 18119/19695] TRAIN loss: 1.479
# [Iteration 18169/19695] TRAIN loss: 1.480
# [Iteration 18219/19695] TRAIN loss: 1.477
# [Iteration 18269/19695] TRAIN loss: 1.472
# [Iteration 18319/19695] TRAIN loss: 1.480
# [Iteration 18369/19695] TRAIN loss: 1.477
# [Epoch 14/15] TRAIN acc/loss: 1.000/1.477
# [Epoch 14/15] VAL   acc/loss: 0.984/1.478
# [Iteration 18432/19695] TRAIN loss: 1.472
# [Iteration 18482/19695] TRAIN loss: 1.468
# [Iteration 18532/19695] TRAIN loss: 1.475
# [Iteration 18582/19695] TRAIN loss: 1.474
# [Iteration 18632/19695] TRAIN loss: 1.478
# [Iteration 18682/19695] TRAIN loss: 1.475
# [Iteration 18732/19695] TRAIN loss: 1.471
# [Iteration 18782/19695] TRAIN loss: 1.472
# [Iteration 18832/19695] TRAIN loss: 1.473
# [Iteration 18882/19695] TRAIN loss: 1.480
# [Iteration 18932/19695] TRAIN loss: 1.475
# [Iteration 18982/19695] TRAIN loss: 1.486
# [Iteration 19032/19695] TRAIN loss: 1.481
# [Iteration 19082/19695] TRAIN loss: 1.472
# [Iteration 19132/19695] TRAIN loss: 1.478
# [Iteration 19182/19695] TRAIN loss: 1.476
# [Iteration 19232/19695] TRAIN loss: 1.481
# [Iteration 19282/19695] TRAIN loss: 1.477
# [Iteration 19332/19695] TRAIN loss: 1.475
# [Iteration 19382/19695] TRAIN loss: 1.477
# [Iteration 19432/19695] TRAIN loss: 1.475
# [Iteration 19482/19695] TRAIN loss: 1.478
# [Iteration 19532/19695] TRAIN loss: 1.476
# [Iteration 19582/19695] TRAIN loss: 1.479
# [Iteration 19632/19695] TRAIN loss: 1.473
# [Iteration 19682/19695] TRAIN loss: 1.482
# [Epoch 15/15] TRAIN acc/loss: 1.000/1.482
# [Epoch 15/15] VAL   acc/loss: 0.981/1.481
# FINISH.

# %% [markdown]
# # Test your Model
# When you are satisfied with your training, you can save the model. In order to be eligible for the bonus points you have to achieve a score higher than __97__.

# %% [markdown]
# ## Save the Model
#
# When you are satisfied with your training, you can save the model.

# %%
os.makedirs('models', exist_ok=True)
model_lstm.save("models/rnn_mnist_nn.model")
# Out:
# Saving model... models/rnn_mnist_nn.model

# %%
jila

# %%
os.makedirs('models', exist_ok=True)
model_rnn.save("models/rnn_mnist_nn.model")
